# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathvariar/FoDS/blob/main/Prior_and_Posterior_Distributions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import beta

# %%
num_points = 100
x = np.linspace(0, 1, num_points)
params = []
means = []
a = 2 #init params
b = 2 #init params
params.append((a,b))
mean = beta.mean(a, b)
means.append(mean)
y0 = beta.pdf(x, a, b) # init distribution
m = 0.8 # % of people who liked
n = 0.2 # % of people who didn't like 
a += m
b += n
params.append((a,b))
y1 = beta.pdf(x, a, b) # 80% liked 20% didnt like (40/50)
print(y1)
print(np.mean(y1), np.where(y1 == np.mean(y1))[0])
print(max(y0), np.where(y0 == max(y0))[0])
# Out:
# [0.         0.00328301 0.01129226 0.02313899 0.03835103 0.05658485
#  0.07756263 0.10104681 0.12682719 0.15471352 0.18453075 0.21611593
#  0.24931596 0.28398599 0.31998816 0.3571907  0.39546715 0.43469577
#  0.47475907 0.51554337 0.5569385  0.5988375  0.6411364  0.68373396
#  0.72653157 0.76943301 0.81234441 0.85517404 0.89783227 0.94023147
#  0.98228589 1.02391164 1.06502662 1.10555041 1.14540432 1.18451124
#  1.22279568 1.26018373 1.29660297 1.33198253 1.36625302 1.39934652
#  1.43119657 1.46173817 1.49090778 1.51864328 1.54488401 1.56957074
#  1.59264571 1.61405261 1.63373661 1.65164436 1.66772402 1.68192529
#  1.69419939 1.70449915 1.71277901 1.71899505 1.72310504 1.72506851
#  1.72484675 1.72240293 1.7177021  1.71071131 1.70139967 1.68973842
#  1.67570108 1.65926348 1.64040397 1.61910348 1.5953457  1.56911727
#  1.54040794 1.50921079 1.47552252 1.43934367 1.40067896 1.35953771
#  1.3159342  1.26988822 1.22142565 1.17057913 1.11738896 1.06190406
#  1.00418323 0.94429664 0.88232782 0.818376   0.75255937 0.68501921
#  0.61592561 0.54548552 0.47395431 0.40165349 0.32899923 0.25655189
#  0.18511195 0.11593801 0.05140527 0.        ]
# 0.9899710166037095 []
# 1.4998469543924096 [50]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(15,4))
ax1.plot(x, y0, "*", label = "(2,2)")
ax2.plot(x, y1, "k--", label = "(2.8, 2)")
ax1.set_title(f'Prior Distribution: Beta(2, 2)', fontsize=18)
ax1.set_xlabel('Value (% of people)', fontsize =16, fontweight='bold', color='gray')
ax1.set_ylabel('Density', fontsize =16, fontweight='bold', color='gray')
ax2.set_title(f'Posterior Distribution: Beta({a}, {b})', fontsize=18)              
ax2.set_xlabel('Value (% of people)', fontsize =16, fontweight='bold', color='gray')
ax2.set_ylabel('Density', fontsize =16, fontweight='bold', color='gray')
# Out:
# Text(0, 0.5, 'Density')

# %%
m = 0.433
n = 0.567
a += m
b += n
print (a, b)
params.append((a,b))
y2 = beta.pdf(x, a, b)
mean = beta.mean(a, b)
means.append(mean)
# Out:
# 3.2329999999999997 2.7670000000000003

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(15,4))
ax1.plot(x, y1, "*", label = f"{params[1]}")
ax2.plot(x, y2, "k--", label = f"{params[2]}")
ax1.set_title(f'Prior Distribution: Beta{params[1]}', fontsize=18)
ax1.set_xlabel('Value (% of people)', fontsize =16, fontweight='bold', color='gray')
ax1.set_ylabel('Density', fontsize =16, fontweight='bold', color='gray')
ax2.set_title(f'Posterior Distribution: Beta{params[2]}', fontsize=18)              
ax2.set_xlabel('Value (% of people)', fontsize =16, fontweight='bold', color='gray')
ax2.set_ylabel('Density', fontsize =16, fontweight='bold', color='gray')
# Out:
# Text(0, 0.5, 'Density')

# %%
m = 0.70
n = 0.3
a += m
b += n
params.append((a, b))
y3 = beta.pdf(x, a, b)
mean = beta.mean(a, b)
means.append(mean)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(15,4))
ax1.plot(x, y2, "*", label = f"{params[2]}")
ax2.plot(x, y3, "k--", label = f"{params[3]}")
ax1.set_title(f'Prior Distribution: Beta{params[2]}', fontsize=18)
ax1.set_xlabel('Value (% of people)', fontsize =16, fontweight='bold', color='gray')
ax1.set_ylabel('Density', fontsize =16, fontweight='bold', color='gray')
ax2.set_title(f'Posterior Distribution: Beta{params[3]}', fontsize=18)              
ax2.set_xlabel('Value (% of people)', fontsize =16, fontweight='bold', color='gray')
ax2.set_ylabel('Density', fontsize =16, fontweight='bold', color='gray')
# Out:
# Text(0, 0.5, 'Density')

# %%
fig, ax = plt.subplots(1, 1, sharex = True, figsize = (15, 4))
ax.plot(x, y0, "b--", label = f"{params[0]}")
ax.vlines(x = means[0], ymin = 0, ymax = y1[np.where(y0 == mean(y0))], color = "b", ls = '--')
ax.plot(x, y1, "r--", label = f"{params[1]}")
ax.plot(x, y2, "k--", label = f"{params[2]}")
ax.plot(x, y3, "g--", label = f"{params[3]}")
ax.set_title(f'Distributions', fontsize=18)              
ax.set_xlabel('Value (% of people)', fontsize =16, fontweight='bold', color='gray')
ax.set_ylabel('Density', fontsize =16, fontweight='bold', color='gray')
ax.legend(fontsize=14, title='Parameters')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-b8ac26c5c99f> in <module>
#       1 fig, ax = plt.subplots(1, 1, sharex = True, figsize = (15, 4))
#       2 ax.plot(x, y0, "b--", label = f"{params[0]}")
# ----> 3 ax.vlines(x = means[0], ymin = 0, ymax = y1[np.where(y0 == mean(y0))], color = "b", ls = '--')
#       4 ax.plot(x, y1, "r--", label = f"{params[1]}")
#       5 ax.plot(x, y2, "k--", label = f"{params[2]}")
#
# TypeError: 'numpy.float64' object is not callable

# %% [markdown]
# i) There are only 2 possibilites, the customer either likes or dislikes the new software update. The probability of customer liking the update is $\mu$ and customer disliking the update is $1-\mu$. The likelihood is the probability of obtaining the survey data given $\mu$.
#
# ii) Derivation as done in class.
